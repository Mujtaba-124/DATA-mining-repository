# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Create random dataset
np.random.seed(42)

data = pd.DataFrame({
    "Feature1": np.random.rand(10) * 100,
    "Feature2": np.random.rand(10) * 100,
    "Feature3": np.random.rand(10) * 100
})

data
# Out:
#     Feature1   Feature2   Feature3
# 0  37.454012   2.058449  61.185289
# 1  95.071431  96.990985  13.949386
# 2  73.199394  83.244264  29.214465
# 3  59.865848  21.233911  36.636184
# 4  15.601864  18.182497  45.606998
# 5  15.599452  18.340451  78.517596
# 6   5.808361  30.424224  19.967378
# 7  86.617615  52.475643  51.423444
# 8  60.111501  43.194502  59.241457
# 9  70.807258  29.122914   4.645041

# %%
# Save dataset
data.to_csv("sample_data.csv", index=False)

# Load dataset
data = pd.read_csv("sample_data.csv")

data.head()
# Out:
#     Feature1   Feature2   Feature3
# 0  37.454012   2.058449  61.185289
# 1  95.071431  96.990985  13.949386
# 2  73.199394  83.244264  29.214465
# 3  59.865848  21.233911  36.636184
# 4  15.601864  18.182497  45.606998

# %%
data["Feature_Sum"] = data["Feature1"] + data["Feature2"]

data
# Out:
#     Feature1   Feature2   Feature3  Feature_Sum
# 0  37.454012   2.058449  61.185289    39.512461
# 1  95.071431  96.990985  13.949386   192.062416
# 2  73.199394  83.244264  29.214465   156.443658
# 3  59.865848  21.233911  36.636184    81.099759
# 4  15.601864  18.182497  45.606998    33.784361
# 5  15.599452  18.340451  78.517596    33.939903
# 6   5.808361  30.424224  19.967378    36.232586
# 7  86.617615  52.475643  51.423444   139.093258
# 8  60.111501  43.194502  59.241457   103.306003
# 9  70.807258  29.122914   4.645041    99.930172

# %%
mean_values = data.mean()
median_values = data.median()
mode_values = data.mode().iloc[0]
std_values = data.std()
correlation_matrix = data.corr()

print("Mean:\n", mean_values)
print("\nMedian:\n", median_values)
print("\nMode:\n", mode_values)
print("\nStandard Deviation:\n", std_values)
print("\nCorrelation Matrix:\n", correlation_matrix)
# Out:
# Mean:
#  Feature1       52.013674
# Feature2       39.526784
# Feature3       40.038724
# Feature_Sum    91.540458
# dtype: float64
#
# Median:
#  Feature1       59.988675
# Feature2       29.773569
# Feature3       41.121591
# Feature_Sum    90.514966
# dtype: float64
#
# Mode:
#  Feature1        5.808361
# Feature2        2.058449
# Feature3        4.645041
# Feature_Sum    33.784361
# Name: 0, dtype: float64
#
# Standard Deviation:
#  Feature1       31.586562
# Feature2       30.237062
# Feature3       23.385965
# Feature_Sum    57.072708
# dtype: float64
#
# Correlation Matrix:
#               Feature1  Feature2  Feature3  Feature_Sum
# Feature1     1.000000  0.704285 -0.372964     0.926574
# Feature2     0.704285  1.000000 -0.450620     0.919581
# Feature3    -0.372964 -0.450620  1.000000    -0.445153
# Feature_Sum  0.926574  0.919581 -0.445153     1.000000

# %%
plt.figure(figsize=(12,8))

plt.subplot(2,2,1)
sns.boxplot(data=data)
plt.title("Boxplot of Features")
# Out:
# Text(0.5, 1.0, 'Boxplot of Features')

# %%
plt.subplot(2,2,2)
plt.hist(data["Feature1"], bins=10)
plt.title("Histogram of Feature1")
# Out:
# Text(0.5, 1.0, 'Histogram of Feature1')

# %%
plt.subplot(2,2,3)
plt.scatter(data["Feature1"], data["Feature2"])
plt.xlabel("Feature1")
plt.ylabel("Feature2")
plt.title("Feature1 vs Feature2")
# Out:
# Text(0.5, 1.0, 'Feature1 vs Feature2')

# %%
plt.subplot(2,2,4)
sns.heatmap(correlation_matrix, annot=True)
plt.title("Correlation Heatmap")

plt.tight_layout()
plt.show()

# %%
data.to_csv("processed_data.csv", index=False)

print("Processed data saved successfully!")
# Out:
# Processed data saved successfully!
